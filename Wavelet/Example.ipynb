# %%
import sys
import os

cur_dir = os.getcwd()
dataset_path = os.path.join(cur_dir, "../Dataset")
wavelets_path = os.path.join(cur_dir, "../Wavelet")
print(wavelets_path)
sys.path.append(dataset_path)
sys.path.append(wavelets_path)
# Out:
# d:\УЧЕБА\Remote monitoring\Wavelet\../Wavelet

# %%
from importlib import reload
import ECGsignal as ecg

reload(ecg)

ecg.init()

# %%
test_ecg = ecg.signal(selected_value=2)
test_ecg = test_ecg[0][:1000]
ecg.plot_signal(3)

# %%
import CWT as wt

reload(wt)
# Out:
# <module 'Wavelet' from 'd:\\УЧЕБА\\Remote monitoring\\Wavelet\\Wavelet.py'>

# %%
print(test_ecg.shape)
# Out:
# (1000,)

# %%
wt.init()
time_m, cw_m, freq_m = wt.cwt_transform(test_ecg, wt.wavelet()[0])

# %%
wt.show_spectr(0)

# %%
wt.show_spectr(6)

# %%
reload(wt)
# Out:
# <module 'Wavelet' from 'd:\\УЧЕБА\\Remote monitoring\\Wavelet\\Wavelet.py'>

# %%
time_d, cw_d, freq_d = wt.cwt_transform(test_ecg, wt.wavelet()[0])

# %%
wt.show_spectr()

# %%
wt.show_spectr(6)

# %%
test_ecg = ecg.signal(selected_value=3)
test_ecg = test_ecg[0][:1000]

# %%
time_d, cw_d, freq_d = wt.cwt_transform(test_ecg, wt.wavelet()[0])

# %%
wt.show_spectr(6)
