# %%
import sys
import os

cur_dir = os.getcwd()
dataset_path = os.path.join(cur_dir, "../Dataset")
wavelets_path = os.path.join(cur_dir, "../Wavelet")
print(wavelets_path)
sys.path.append(dataset_path)
sys.path.append(wavelets_path)
# Out:
# d:\УЧЕБА\Remote monitoring\Wavelet\../Wavelet

# %%
from importlib import reload
import ECGsignal as ecg

reload(ecg)

ecg.init()

# %%
test_ecg = ecg.signal(patient_num=2)
test_ecg = test_ecg["data"][0][:1000]
ecg.plot_signal(3)

# %%
import CWT as wt

reload(wt)
# Out:
# <module 'CWT' from 'd:\\УЧЕБА\\Remote monitoring\\Wavelet\\CWT.py'>

# %%
print(test_ecg.shape)
# Out:
# (12, 2500)

# %%
wt.init()
time_m, cw_m, freq_m = wt.cwt_transform(test_ecg, wt.wavelet()[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 wt.init()
# ----> 2 time_m, cw_m, freq_m = wt.cwt_transform(test_ecg, wt.wavelet()[0])
#
# File d:\УЧЕБА\Remote monitoring\Wavelet\CWT.py:43, in cwt_transform(x, method)
#      41 N = x.shape[1]
#      42 for sig in x:
# ---> 43     time, cwt, f = transform(sig, method)
#      44     result_cwt.append(cwt)
#      45     freq_res.append(f)
#
# File d:\УЧЕБА\Remote monitoring\Wavelet\CWT.py:31, in transform(x, method)
#      28 x = detrend_normalize(x)
#      29 time, scales = cwt_scales(x)
# ---> 31 cwtmatr, freqs = pywt.cwt(x, scales, method)
#      33 return time, cwtmatr, freqs
#
# File d:\anaconda3\Lib\site-packages\pywt\_cwt.py:158, in cwt(data, scales, wavelet, sampling_period, method, axis)
#     156 if method == 'conv':
#     157     if data.ndim == 1:
# --> 158         conv = np.convolve(data, int_psi_scale)
#     159     else:
#     160         # batch convolution via loop
#     161         conv_shape = list(data.shape)
#
# File <__array_function__ internals>:200, in convolve(*args, **kwargs)
#
# File d:\anaconda3\Lib\site-packages\numpy\core\numeric.py:851, in convolve(a, v, mode)
#     849 if len(v) == 0:
#     850     raise ValueError('v cannot be empty')
# --> 851 return multiarray.correlate(a, v[::-1], mode)
#
# KeyboardInterrupt:

# %%
wt.show_spectr(0)

# %%
wt.show_spectr(6)

# %%
reload(wt)
# Out:
# <module 'CWT' from 'd:\\УЧЕБА\\Remote monitoring\\Wavelet\\CWT.py'>

# %%
time_d, cw_d, freq_d = wt.cwt_transform(test_ecg, wt.wavelet()[0])

# %%
wt.show_spectr()

# %%
wt.show_spectr(6)

# %%
reload(wt)
# Out:
# <module 'CWT' from 'd:\\УЧЕБА\\Remote monitoring\\Wavelet\\CWT.py'>

# %%
test_ecg = ecg.signal(patient_num=3)

# %%
cw_df = wt.cwt_transform_df(ECG_df=test_ecg.copy(), n_term_start=0, n_term_finish=3, method=wt.wavelet()[0])

# %%
wt.show_spectr(0)

# %%
wt.show_spectr(1)
